# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from analysis import LoadData
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dropout, Input
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-08-19 15:42:31.754643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-19 15:42:31.765161: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-19 15:42:31.768334: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-19 15:42:31.775834: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-19 15:42:32.295306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724078552.791616   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078552.815683   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078552.818812   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Load data

# %%
train_dir = 'data/train/'
val_dir = 'data/val/'
test_dir = 'data/test/'

labels_list_str = ['normal', 'pneumonia']

# %%
img_size = 512


x_train, y_train = LoadData(train_dir, labels_list_str, img_size = img_size)
x_val, y_val = LoadData(val_dir, labels_list_str, img_size = img_size)
x_test, y_test = LoadData(test_dir, labels_list_str, img_size = img_size)
# Out:
# data/train/normal
# data/train/pneumonia
# data/val/normal
# data/val/pneumonia
# data/test/normal
# data/test/pneumonia

# %% [markdown]
# ## Image preview

# %%
plt.figure()
plt.imshow(x_train[0], cmap = 'gray')
plt.title(labels_list_str[y_train[0]])
plt.show()

plt.figure()
plt.imshow(x_train[-1], cmap = 'gray')
plt.title(labels_list_str[y_train[-1]])
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
train_datagen = ImageDataGenerator(
    rotation_range = 30,
    zoom_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True
)
train_datagen.fit(x_train)

# %% [markdown]
# ## Model
#
# Initial basic CNN model
# CNN1:

# %%
# optimizer = Adam(learning_rate=1.e-3)

# model = Sequential()

# model.add(Input(shape=(img_size, img_size, 1)))

# model.add(Conv2D(32,(3,3), activation='relu'))
# model.add(MaxPooling2D((2,2)))

# model.add(Conv2D(64, (3,3), activation = 'relu'))
# model.add(MaxPooling2D((2,2)))

# model.add(Conv2D(128, (3,3), activation = 'relu'))
# model.add(MaxPooling2D((2,2)))

# model.add(Conv2D(128, (3,3), activation = 'relu'))
# model.add(MaxPooling2D((2,2)))

# model.add(Flatten())

# model.add(Dense(512, activation = 'relu'))
# model.add(Dropout(0.5))

# model.add(Dense(1, activation = 'sigmoid'))

# model.compile(optimizer = optimizer,
#               loss = 'binary_crossentropy',
#               metrics = ['accuracy'])

# model.summary()
# Out:
# I0000 00:00:1724072225.683731   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724072225.689031   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724072225.696220   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724072225.809734   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724072225.810922   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724072225.811960   76637 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-19 13:57:05.812917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21991 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 510, 510, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 255, 255, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 253, 253, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 124, 124, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 62, 62, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 60, 60, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    58,982,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,223,681 (225.92 MB)
#  Trainable params: 59,223,681 (225.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# CNN2:

# %%
optimizer = Adam(learning_rate=1e-3)

model = Sequential()

model.add(Input(shape=(img_size, img_size, 1)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(512, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation = 'sigmoid'))

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# I0000 00:00:1724078571.265346   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078571.269979   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078571.273412   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078571.372379   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078571.373408   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1724078571.374393   96397 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-19 15:42:51.375347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21987 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 510, 510, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 510, 510, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 255, 255, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 253, 253, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 253, 253, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 124, 124, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 124, 124, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 62, 62, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 60, 60, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    58,982,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,225,089 (225.93 MB)
#  Trainable params: 59,224,385 (225.92 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                 patience = 3,
                                 verbose = 1,
                                 factor = 0.3,
                                 min_lr = 1.e-6)

# %%
K.clear_session()

# %%
history = model.fit(
    train_datagen.flow(x_train, y_train, batch_size=16),
    validation_data=(x_val, y_val),
    epochs=200,
    callbacks = [lr_reduction] 
)
# Out:
# Epoch 1/200
# /home/george/miniconda3/envs/ml_tf/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724078575.385536   96556 service.cc:146] XLA service 0x74a084016a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724078575.385552   96556 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-08-19 15:42:55.428362: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-19 15:42:55.666991: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 29:32 8s/step - accuracy: 0.4375 - loss: 1.4892
# I0000 00:00:1724078580.717465   96556 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 44s 164ms/step - accuracy: 0.8086 - loss: 4.9379 - val_accuracy: 0.3650 - val_loss: 5.0078 - learning_rate: 0.0010
# Epoch 2/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.8620 - loss: 0.9681 - val_accuracy: 0.7472 - val_loss: 31.7346 - learning_rate: 0.0010
# Epoch 3/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.8604 - loss: 0.4251 - val_accuracy: 0.5681 - val_loss: 0.8368 - learning_rate: 0.0010
# Epoch 4/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8836 - loss: 0.2831 - val_accuracy: 0.3676 - val_loss: 0.8502 - learning_rate: 0.0010
# Epoch 5/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8699 - loss: 0.3245 - val_accuracy: 0.9272 - val_loss: 0.2656 - learning_rate: 0.0010
# Epoch 6/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8818 - loss: 0.3192 - val_accuracy: 0.7198 - val_loss: 4.7636 - learning_rate: 0.0010
# Epoch 7/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.8954 - loss: 0.3156 - val_accuracy: 0.9203 - val_loss: 0.2260 - learning_rate: 0.0010
# Epoch 8/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8929 - loss: 0.2744 - val_accuracy: 0.9289 - val_loss: 0.2403 - learning_rate: 0.0010
# Epoch 9/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.8874 - loss: 0.3942 - val_accuracy: 0.8235 - val_loss: 0.6078 - learning_rate: 0.0010
# Epoch 10/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.8741 - loss: 0.3315 - val_accuracy: 0.8595 - val_loss: 0.8245 - learning_rate: 0.0010
# Epoch 11/200
# 218/219 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8843 - loss: 0.2999
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.8843 - loss: 0.3001 - val_accuracy: 0.3068 - val_loss: 44.7592 - learning_rate: 0.0010
# Epoch 12/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.8983 - loss: 0.2771 - val_accuracy: 0.8638 - val_loss: 0.3370 - learning_rate: 3.0000e-04
# Epoch 13/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.9185 - loss: 0.2246 - val_accuracy: 0.8458 - val_loss: 0.4625 - learning_rate: 3.0000e-04
# Epoch 14/200
# 218/219 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9218 - loss: 0.2091
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9218 - loss: 0.2092 - val_accuracy: 0.9135 - val_loss: 0.3078 - learning_rate: 3.0000e-04
# Epoch 15/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9253 - loss: 0.2160 - val_accuracy: 0.9469 - val_loss: 0.1759 - learning_rate: 9.0000e-05
# Epoch 16/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.
200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9313 - loss: 0.1976 - val_accuracy: 0.9349 - val_loss: 0.1813 - learning_rate: 1.0000e-06
# Epoch 63/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9353 - loss: 0.1759 - val_accuracy: 0.9374 - val_loss: 0.1779 - learning_rate: 1.0000e-06
# Epoch 64/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9341 - loss: 0.1912 - val_accuracy: 0.9374 - val_loss: 0.1782 - learning_rate: 1.0000e-06
# Epoch 65/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9405 - loss: 0.1627 - val_accuracy: 0.9349 - val_loss: 0.1805 - learning_rate: 1.0000e-06
# Epoch 66/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9443 - loss: 0.1667 - val_accuracy: 0.9340 - val_loss: 0.1838 - learning_rate: 1.0000e-06
# Epoch 67/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9422 - loss: 0.1728 - val_accuracy: 0.9340 - val_loss: 0.1840 - learning_rate: 1.0000e-06
# Epoch 68/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9389 - loss: 0.1643 - val_accuracy: 0.9366 - val_loss: 0.1798 - learning_rate: 1.0000e-06
# Epoch 69/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9338 - loss: 0.1809 - val_accuracy: 0.9340 - val_loss: 0.1817 - learning_rate: 1.0000e-06
# Epoch 70/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9336 - loss: 0.1753 - val_accuracy: 0.9357 - val_loss: 0.1786 - learning_rate: 1.0000e-06
# Epoch 71/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9387 - loss: 0.1761 - val_accuracy: 0.9357 - val_loss: 0.1762 - learning_rate: 1.0000e-06
# Epoch 72/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9361 - loss: 0.1772 - val_accuracy: 0.9357 - val_loss: 0.1789 - learning_rate: 1.0000e-06
# Epoch 73/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9433 - loss: 0.1564 - val_accuracy: 0.9366 - val_loss: 0.1765 - learning_rate: 1.0000e-06
# Epoch 74/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9271 - loss: 0.1980 - val_accuracy: 0.9357 - val_loss: 0.1811 - learning_rate: 1.0000e-06
# Epoch 75/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9466 - loss: 0.1594 - val_accuracy: 0.9366 - val_loss: 0.1792 - learning_rate: 1.0000e-06
# Epoch 76/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9422 - loss: 0.1661 - val_accuracy: 0.9366 - val_loss: 0.1785 - learning_rate: 1.0000e-06
# Epoch 77/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9335 - loss: 0.1730 - val_accuracy: 0.9323 - val_loss: 0.1813 - learning_rate: 1.0000e-06
# Epoch 78/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9357 - loss: 0.1635 - val_accuracy: 0.9340 - val_loss: 0.1819 - learning_rate: 1.0000e-06
# Epoch 79/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.9347 - loss: 0.1833 - val_accuracy: 0.9349 - val_loss: 0.1794 - learning_rate: 1.0000e-06
# Epoch 80/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9318 - loss: 0.1774 - val_accuracy: 0.9366 - val_loss: 0.1770 - learning_rate: 1.0000e-06
# Epoch 81/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9402 - loss: 0.1692 - val_accuracy: 0.9357 - val_loss: 0.1790 - learning_rate: 1.0000e-06
# Epoch 82/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9268 - loss: 0.1853 - val_accuracy: 0.9349 - val_loss: 0.1810 - learning_rate: 1.0000e-06
# Epoch 83/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9408 - loss: 0.1703 - val_accuracy: 0.9340 - val_loss: 0.1813 - learning_rate: 1.0000e-06
# Epoch 84/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9406 - loss: 0.1638 - val_accuracy: 0.9323 - val_loss: 0.1823 - learning_rate: 1.0000e-06
# Epoch 85/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9438 - loss: 0.1679 - val_accuracy: 0.9323 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 86/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9304 - loss: 0.1835 - val_accuracy: 0.9374 - val_loss: 0.1757 - learning_rate: 1.0000e-06
# Epoch 87/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9382 - loss: 0.1698 - val_accuracy: 0.9349 - val_loss: 0.1793 - learning_rate: 1.0000e-06
# Epoch 88/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.9415 - loss: 0.1717 - val_accuracy: 0.9366 - val_loss: 0.1785 - learning_rate: 1.0000e-06
# Epoch 89/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9435 - loss: 0.1712 - val_accuracy: 0.9366 - val_loss: 0.1769 - learning_rate: 1.0000e-06
# Epoch 90/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9387 - loss: 0.1758 - val_accuracy: 0.9366 - val_loss: 0.1777 - learning_rate: 1.0000e-06
# Epoch 91/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9321 - loss: 0.1808 - val_accuracy: 0.9374 - val_loss: 0.1791 - learning_rate: 1.0000e-06
# Epoch 92/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9421 - loss: 0.1727 - val_accuracy: 0.9383 - val_loss: 0.1753 - learning_rate: 1.0000e-06
# Epoch 93/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9369 - loss: 0.1569 - val_accuracy: 0.9366 - val_loss: 0.1779 - learning_rate: 1.0000e-06
# Epoch 94/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9374 - loss: 0.1620 - val_accuracy: 0.9323 - val_loss: 0.1812 - learning_rate: 1.0000e-06
# Epoch 95/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9411 - loss: 0.1706 - val_accuracy: 0.9357 - val_loss: 0.1791 - learning_rate: 1.0000e-06
# Epoch 96/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9441 - loss: 0.1687 - val_accuracy: 0.9374 - val_loss: 0.1762 - learning_rate: 1.0000e-06
# Epoch 97/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9395 - loss: 0.1575 - val_accuracy: 0.9357 - val_loss: 0.1776 - learning_rate: 1.0000e-06
# Epoch 98/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9360 - loss: 0.1593 - val_accuracy: 0.9374 - val_loss: 0.1762 - learning_rate: 1.0000e-06
# Epoch 99/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9368 - loss: 0.1706 - val_accuracy: 0.9374 - val_loss: 0.1770 - learning_rate: 1.0000e-06
# Epoch 100/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9417 - loss: 0.1641 - val_accuracy: 0.9340 - val_loss: 0.1798 - learning_rate: 1.0000e-06
# Epoch 101/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9412 - loss: 0.1647 - val_accuracy: 0.9366 - val_loss: 0.1778 - learning_rate: 1.0000e-06
# Epoch 102/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9402 - loss: 0.1674 - val_accuracy: 0.9383 - val_loss: 0.1750 - learning_rate: 1.0000e-06
# Epoch 103/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9352 - loss: 0.1865 - val_accuracy: 0.9357 - val_loss: 0.1792 - learning_rate: 1.0000e-06
# Epoch 104/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9357 - loss: 0.1732 - val_accuracy: 0.9349 - val_loss: 0.1785 - learning_rate: 1.0000e-06
# Epoch 105/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9365 - loss: 0.1779 - val_accuracy: 0.9357 - val_loss: 0.1807 - learning_rate: 1.0000e-06
# Epoch 106/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9412 - loss: 0.1551 - val_accuracy: 0.9349 - val_loss: 0.1791 - learning_rate: 1.0000e-06
# Epoch 107/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9410 - loss: 0.1639 - val_accuracy: 0.9357 - val_loss: 0.1779 - learning_rate: 1.0000e-06
# Epoch 108/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9377 - loss: 0.1656 - val_accuracy: 0.9357 - val_loss: 0.1798 - learning_rate: 1.0000e-06
# Epoch 109/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9448 - loss: 0.1728 - val_accuracy: 0.9383 - val_loss: 0.1760 - learning_rate: 1.0000e-06
# Epoch 110/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9469 - loss: 0.1642 - val_accuracy: 0.9349 - val_loss: 0.1816 - learning_rate: 1.0000e-06
# Epoch 111/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9422 - loss: 0.1616 - val_accuracy: 0.9349 - val_loss: 0.1819 - learning_rate: 1.0000e-06
# Epoch 112/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9446 - loss: 0.1462 - val_accuracy: 0.9357 - val_loss: 0.1787 - learning_rate: 1.0000e-06
# Epoch 113/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9456 - loss: 0.1556 - val_accuracy: 0.9349 - val_loss: 0.1796 - learning_rate: 1.0000e-06
# Epoch 114/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9289 - loss: 0.1866 - val_accuracy: 0.9357 - val_loss: 0.1804 - learning_rate: 1.0000e-06
# Epoch 115/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9402 - loss: 0.1643 - val_accuracy: 0.9349 - val_loss: 0.1785 - learning_rate: 1.0000e-06
# Epoch 116/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9406 - loss: 0.1605 - val_accuracy: 0.9340 - val_loss: 0.1816 - learning_rate: 1.0000e-06
# Epoch 117/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9455 - loss: 0.1584 - val_accuracy: 0.9374 - val_loss: 0.1755 - learning_rate: 1.0000e-06
# Epoch 118/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9371 - loss: 0.1793 - val_accuracy: 0.9400 - val_loss: 0.1756 - learning_rate: 1.0000e-06
# Epoch 119/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9442 - loss: 0.1788 - val_accuracy: 0.9392 - val_loss: 0.1757 - learning_rate: 1.0000e-06
# Epoch 120/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9328 - loss: 0.1818 - val_accuracy: 0.9349 - val_loss: 0.1808 - learning_rate: 1.0000e-06
# Epoch 121/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9369 - loss: 0.1721 - val_accuracy: 0.9357 - val_loss: 0.1805 - learning_rate: 1.0000e-06
# Epoch 122/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9351 - loss: 0.1704 - val_accuracy: 0.9357 - val_loss: 0.1789 - learning_rate: 1.0000e-06
# Epoch 123/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9430 - loss: 0.1682 - val_accuracy: 0.9357 - val_loss: 0.1804 - learning_rate: 1.0000e-06
# Epoch 124/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9402 - loss: 0.1696 - val_accuracy: 0.9357 - val_loss: 0.1800 - learning_rate: 1.0000e-06
# Epoch 125/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9530 - loss: 0.1565 - val_accuracy: 0.9366 - val_loss: 0.1783 - learning_rate: 1.0000e-06
# Epoch 126/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9352 - loss: 0.1709 - val_accuracy: 0.9366 - val_loss: 0.1769 - learning_rate: 1.0000e-06
# Epoch 127/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.9459 - loss: 0.1552 - val_accuracy: 0.9374 - val_loss: 0.1797 - learning_rate: 1.0000e-06
# Epoch 128/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9422 - loss: 0.1602 - val_accuracy: 0.9357 - val_loss: 0.1805 - learning_rate: 1.0000e-06
# Epoch 129/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9454 - loss: 0.1681 - val_accuracy: 0.9357 - val_loss: 0.1791 - learning_rate: 1.0000e-06
# Epoch 130/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9459 - loss: 0.1606 - val_accuracy: 0.9374 - val_loss: 0.1759 - learning_rate: 1.0000e-06
# Epoch 131/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9461 - loss: 0.1509 - val_accuracy: 0.9357 - val_loss: 0.1808 - learning_rate: 1.0000e-06
# Epoch 132/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9379 - loss: 0.1674 - val_accuracy: 0.9366 - val_loss: 0.1791 - learning_rate: 1.0000e-06
# Epoch 133/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9368 - loss: 0.1813 - val_accuracy: 0.9374 - val_loss: 0.1762 - learning_rate: 1.0000e-06
# Epoch 134/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9400 - loss: 0.1686 - val_accuracy: 0.9357 - val_loss: 0.1794 - learning_rate: 1.0000e-06
# Epoch 135/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9344 - loss: 0.1840 - val_accuracy: 0.9366 - val_loss: 0.1790 - learning_rate: 1.0000e-06
# Epoch 136/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9425 - loss: 0.1545 - val_accuracy: 0.9357 - val_loss: 0.1787 - learning_rate: 1.0000e-06
# Epoch 137/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9387 - loss: 0.1610 - val_accuracy: 0.9357 - val_loss: 0.1796 - learning_rate: 1.0000e-06
# Epoch 138/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9394 - loss: 0.1623 - val_accuracy: 0.9357 - val_loss: 0.1823 - learning_rate: 1.0000e-06
# Epoch 139/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9422 - loss: 0.1748 - val_accuracy: 0.9366 - val_loss: 0.1772 - learning_rate: 1.0000e-06
# Epoch 140/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9376 - loss: 0.1756 - val_accuracy: 0.9366 - val_loss: 0.1774 - learning_rate: 1.0000e-06
# Epoch 141/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9393 - loss: 0.1774 - val_accuracy: 0.9366 - val_loss: 0.1790 - learning_rate: 1.0000e-06
# Epoch 142/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9479 - loss: 0.1511 - val_accuracy: 0.9366 - val_loss: 0.1816 - learning_rate: 1.0000e-06
# Epoch 143/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9407 - loss: 0.1565 - val_accuracy: 0.9366 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 144/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.9386 - loss: 0.1724 - val_accuracy: 0.9366 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 145/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9350 - loss: 0.1635 - val_accuracy: 0.9366 - val_loss: 0.1816 - learning_rate: 1.0000e-06
# Epoch 146/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9428 - loss: 0.1495 - val_accuracy: 0.9366 - val_loss: 0.1781 - learning_rate: 1.0000e-06
# Epoch 147/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9321 - loss: 0.2048 - val_accuracy: 0.9366 - val_loss: 0.1777 - learning_rate: 1.0000e-06
# Epoch 148/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9452 - loss: 0.1611 - val_accuracy: 0.9357 - val_loss: 0.1785 - learning_rate: 1.0000e-06
# Epoch 149/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.9466 - loss: 0.1521 - val_accuracy: 0.9366 - val_loss: 0.1802 - learning_rate: 1.0000e-06
# Epoch 150/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9282 - loss: 0.1996 - val_accuracy: 0.9357 - val_loss: 0.1790 - learning_rate: 1.0000e-06
# Epoch 151/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9437 - loss: 0.1629 - val_accuracy: 0.9366 - val_loss: 0.1828 - learning_rate: 1.0000e-06
# Epoch 152/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9462 - loss: 0.1715 - val_accuracy: 0.9366 - val_loss: 0.1800 - learning_rate: 1.0000e-06
# Epoch 153/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9461 - loss: 0.1410 - val_accuracy: 0.9366 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 154/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9531 - loss: 0.1434 - val_accuracy: 0.9366 - val_loss: 0.1819 - learning_rate: 1.0000e-06
# Epoch 155/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9431 - loss: 0.1564 - val_accuracy: 0.9366 - val_loss: 0.1829 - learning_rate: 1.0000e-06
# Epoch 156/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.9281 - loss: 0.1758 - val_accuracy: 0.9357 - val_loss: 0.1814 - learning_rate: 1.0000e-06
# Epoch 157/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9439 - loss: 0.1614 - val_accuracy: 0.9366 - val_loss: 0.1822 - learning_rate: 1.0000e-06
# Epoch 158/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9357 - loss: 0.1686 - val_accuracy: 0.9366 - val_loss: 0.1820 - learning_rate: 1.0000e-06
# Epoch 159/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9459 - loss: 0.1595 - val_accuracy: 0.9366 - val_loss: 0.1787 - learning_rate: 1.0000e-06
# Epoch 160/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9391 - loss: 0.1648 - val_accuracy: 0.9366 - val_loss: 0.1802 - learning_rate: 1.0000e-06
# Epoch 161/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9467 - loss: 0.1502 - val_accuracy: 0.9366 - val_loss: 0.1830 - learning_rate: 1.0000e-06
# Epoch 162/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9376 - loss: 0.1646 - val_accuracy: 0.9366 - val_loss: 0.1768 - learning_rate: 1.0000e-06
# Epoch 163/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9511 - loss: 0.1594 - val_accuracy: 0.9366 - val_loss: 0.1814 - learning_rate: 1.0000e-06
# Epoch 164/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9450 - loss: 0.1715 - val_accuracy: 0.9366 - val_loss: 0.1827 - learning_rate: 1.0000e-06
# Epoch 165/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 140ms/step - accuracy: 0.9429 - loss: 0.1598 - val_accuracy: 0.9374 - val_loss: 0.1780 - learning_rate: 1.0000e-06
# Epoch 166/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9436 - loss: 0.1565 - val_accuracy: 0.9366 - val_loss: 0.1798 - learning_rate: 1.0000e-06
# Epoch 167/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 140ms/step - accuracy: 0.9418 - loss: 0.1786 - val_accuracy: 0.9383 - val_loss: 0.1773 - learning_rate: 1.0000e-06
# Epoch 168/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9414 - loss: 0.1734 - val_accuracy: 0.9374 - val_loss: 0.1792 - learning_rate: 1.0000e-06
# Epoch 169/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9403 - loss: 0.1672 - val_accuracy: 0.9366 - val_loss: 0.1788 - learning_rate: 1.0000e-06
# Epoch 170/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9353 - loss: 0.1662 - val_accuracy: 0.9366 - val_loss: 0.1836 - learning_rate: 1.0000e-06
# Epoch 171/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9404 - loss: 0.1567 - val_accuracy: 0.9374 - val_loss: 0.1780 - learning_rate: 1.0000e-06
# Epoch 172/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9333 - loss: 0.1701 - val_accuracy: 0.9366 - val_loss: 0.1819 - learning_rate: 1.0000e-06
# Epoch 173/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9314 - loss: 0.1926 - val_accuracy: 0.9366 - val_loss: 0.1829 - learning_rate: 1.0000e-06
# Epoch 174/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9422 - loss: 0.1568 - val_accuracy: 0.9366 - val_loss: 0.1821 - learning_rate: 1.0000e-06
# Epoch 175/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9389 - loss: 0.1708 - val_accuracy: 0.9357 - val_loss: 0.1841 - learning_rate: 1.0000e-06
# Epoch 176/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9340 - loss: 0.1653 - val_accuracy: 0.9366 - val_loss: 0.1792 - learning_rate: 1.0000e-06
# Epoch 177/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9444 - loss: 0.1611 - val_accuracy: 0.9366 - val_loss: 0.1788 - learning_rate: 1.0000e-06
# Epoch 178/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9372 - loss: 0.1646 - val_accuracy: 0.9366 - val_loss: 0.1799 - learning_rate: 1.0000e-06
# Epoch 179/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9433 - loss: 0.1668 - val_accuracy: 0.9366 - val_loss: 0.1814 - learning_rate: 1.0000e-06
# Epoch 180/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.9420 - loss: 0.1615 - val_accuracy: 0.9366 - val_loss: 0.1802 - learning_rate: 1.0000e-06
# Epoch 181/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9393 - loss: 0.1739 - val_accuracy: 0.9357 - val_loss: 0.1824 - learning_rate: 1.0000e-06
# Epoch 182/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9351 - loss: 0.1706 - val_accuracy: 0.9374 - val_loss: 0.1784 - learning_rate: 1.0000e-06
# Epoch 183/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9453 - loss: 0.1499 - val_accuracy: 0.9374 - val_loss: 0.1788 - learning_rate: 1.0000e-06
# Epoch 184/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9433 - loss: 0.1537 - val_accuracy: 0.9366 - val_loss: 0.1820 - learning_rate: 1.0000e-06
# Epoch 185/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9367 - loss: 0.1587 - val_accuracy: 0.9366 - val_loss: 0.1792 - learning_rate: 1.0000e-06
# Epoch 186/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9384 - loss: 0.1647 - val_accuracy: 0.9374 - val_loss: 0.1770 - learning_rate: 1.0000e-06
# Epoch 187/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9435 - loss: 0.1521 - val_accuracy: 0.9357 - val_loss: 0.1814 - learning_rate: 1.0000e-06
# Epoch 188/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.9427 - loss: 0.1643 - val_accuracy: 0.9366 - val_loss: 0.1798 - learning_rate: 1.0000e-06
# Epoch 189/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9466 - loss: 0.1457 - val_accuracy: 0.9374 - val_loss: 0.1779 - learning_rate: 1.0000e-06
# Epoch 190/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9422 - loss: 0.1679 - val_accuracy: 0.9357 - val_loss: 0.1817 - learning_rate: 1.0000e-06
# Epoch 191/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9500 - loss: 0.1475 - val_accuracy: 0.9366 - val_loss: 0.1786 - learning_rate: 1.0000e-06
# Epoch 192/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9458 - loss: 0.1530 - val_accuracy: 0.9357 - val_loss: 0.1783 - learning_rate: 1.0000e-06
# Epoch 193/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9372 - loss: 0.1764 - val_accuracy: 0.9357 - val_loss: 0.1829 - learning_rate: 1.0000e-06
# Epoch 194/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.9411 - loss: 0.1702 - val_accuracy: 0.9349 - val_loss: 0.1788 - learning_rate: 1.0000e-06
# Epoch 195/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9421 - loss: 0.1895 - val_accuracy: 0.9357 - val_loss: 0.1789 - learning_rate: 1.0000e-06
# Epoch 196/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.9410 - loss: 0.1600 - val_accuracy: 0.9366 - val_loss: 0.1765 - learning_rate: 1.0000e-06
# Epoch 197/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9397 - loss: 0.1635 - val_accuracy: 0.9366 - val_loss: 0.1780 - learning_rate: 1.0000e-06
# Epoch 198/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.9423 - loss: 0.1667 - val_accuracy: 0.9366 - val_loss: 0.1757 - learning_rate: 1.0000e-06
# Epoch 199/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 32s 139ms/step - accuracy: 0.9387 - loss: 0.1798 - val_accuracy: 0.9366 - val_loss: 0.1764 - learning_rate: 1.0000e-06
# Epoch 200/200
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 31s 135ms/step - accuracy: 0.9402 - loss: 0.1571 - val_accuracy: 0.9366 - val_loss: 0.1800 - learning_rate: 1.0000e-06

# %%
model.save('CNN2.keras')

# %%
import json
with open('history2.json', 'w') as f:
    json.dump(history.history, f)
